# %%
import os
import random
import pickle
import time
class Game:
    def __init__(self):
        self.board = [0 for i in range(9)]
        self.result = None
        self.qtable = dict()
        try:
            print('Tictactoe bot training')
            print('loading...')
            with open('bot.db', 'r') as db:
                lines = db.readlines()
                for line in lines:
                    k, v = line.split('|')
                    v = int(v[:-1])
                    if k in self.qtable.keys():
                        self.qtable[k].append(v)
                        self.qtable[k] = list(set(self.qtable[k]))
                    else:
                        self.qtable[k] = [v]
        except FileNotFoundError:
            print('db not found')
        time.sleep(1)

    def _reference(self):
        ref = [i for i in range(9)]
        print(f'{ref[0]}|{ref[1]}|{ref[2]}\n{ref[3]}|{ref[4]}|{ref[5]}\n{ref[6]}|{ref[7]}|{ref[8]}\n')
    def __str__(self):
        symbol = lambda x: 'X' if x == 1 else 'O' if x == -1 else ' '
        board = f'{symbol(self.board[0])}|{symbol(self.board[1])}|{symbol(self.board[2])}\n{symbol(self.board[3])}|{symbol(self.board[4])}|{symbol(self.board[5])}\n{symbol(self.board[6])}|{symbol(self.board[7])}|{symbol(self.board[8])}\n'
        return board
    def get_hash(self):
        board_hash = ''.join(str(i) for i in self.board) 
        return board_hash
    def _clear(self):
        os.system('cls||clear')
    def dumb_AI(self, history):
        board_hash = self.get_hash()
        roll = (random.choice(list(range(3))) != 0 )#33% random moves?
        if roll:
            if board_hash in self.qtable:
                move = self.qtable[board_hash]
                move = random.choice(move)
                if move not in history:
                    print('from db')
                    return move
            else:
                print('random bs')
                return random.choice(list(set(range(9))-set(history)))
        else:
            print('exploratory random bs')
            return random.choice(list(set(range(9))-set(history)))
    def _check(self, choice, n_moves):
        #  1: player 1 wins
        # -1: player 2 wins
        #  3: game not completed
        #  0: draw

        if n_moves == 9:
            s = self.board[0] + self.board[1] + self.board[2]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[3] + self.board[4] + self.board[5]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[6] + self.board[7] + self.board[8]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[1] + self.board[4] + self.board[7]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[2] + self.board[5] + self.board[8]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[0] + self.board[3] + self.board[6]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[0] + self.board[4] + self.board[8]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[6] + self.board[4] + self.board[2]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            return 0
        if n_moves >= 5:
            s = self.board[0] + self.board[1] + self.board[2]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[3] + self.board[4] + self.board[5]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[6] + self.board[7] + self.board[8]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[1] + self.board[4] + self.board[7]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[2] + self.board[5] + self.board[8]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[0] + self.board[3] + self.board[6]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[0] + self.board[4] + self.board[8]
            if s == 3:
                return 1
            elif s == -3:
                return -1
            s = self.board[6] + self.board[4] + self.board[2]
            if s == 3:
                return 1
            elif s == -3:
                return -1
        return 3
        

    def play(self):
        self._clear()
        turn = 0
        history = [] #self or no self
        bot_moves = dict()
        n_moves = 0
        self._clear()
        self._reference()
        print(self)
        #self._reference()
        while True:
            if not(turn):
                bot_choice = self.dumb_AI(history)
                history.append(bot_choice)
                #print(f'game state: {str(self.get_hash())}')
                #print(f'bot choice: {bot_choice}')
                bot_moves[str(self.get_hash())] = bot_choice
                self.board[bot_choice] = 1
            else:
                bot_choice = self.dumb_AI(history)
                history.append(bot_choice)
                #print(f'game state: {str(self.get_hash())}')
                #print(f'bot choice: {bot_choice}')
                bot_moves[str(self.get_hash())] = bot_choice
                self.board[bot_choice] = -1
            n_moves += 1
            turn = int(not(turn))
            result = self._check(bot_choice, n_moves)
            self._clear()
            self._reference()
            print(self)
            if result == 0:
                print('draw')
                return 0
            elif result == 1:
                print('bot A wins')
                
                for state in bot_moves:
                    with open('bot.db', 'a') as db:
                        db.write(f"{state}|{bot_moves[state]}\n")
                #load db method?
                return 1
            elif result == -1:
                print('bot B wins')
                
                for state in bot_moves:
                    with open('bot.db', 'a') as db:
                        db.write(f"{state}|{bot_moves[state]}\n")
                return -1


g = Game()
g.play()
# Out:
# Tictactoe bot training
# loading...
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
#  | |
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
#  | |
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
#  | |
# X|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
#  | |O
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
#  |X|O
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
#  |X|O
# X|O|O
#
# bot B wins
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# -1

# %%
for i in range(100):
    g = Game()
    g.play()
# Out:
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X|X|
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|X|
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|X|
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|O
# X|X|
#  |X|
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|X|X
# O| |
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|X|X
# O| |
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X| |X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X| |X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |O
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |O
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X| |O
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|X|O
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|X|O
# X|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X|X|O
# X|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  | |X
#  |X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
#  | |X
#  |X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O| |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O|X|X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O|X|X
# O|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O|X|X
# O|X|O
#
# draw
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|X
# X| |
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|X
# X| |
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|X
# X| |
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|X
# X| |O
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# X| |O
# X| |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|X
# O| |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|O
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
# X|O|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|X|O
# X|O|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
# X|X|O
# X|O|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|X
# O| |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |
# X|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |O
# X|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O|X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |O
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# X| |O
# X| |
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|O
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
#  |O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|X|O
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X|X|O
# O|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|X|O
# O|O|X
#
# draw
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  |O|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
# X|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  |X|
# X|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  |X|
# X|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |O
#  |X|
# X|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |O
# X|X|
# X|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |O
# X|X|O
# X|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# X|X|O
# X|O|X
#
# draw
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  |O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  |X|
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  |X|
# O|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# X|X|
# O|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X|X|
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X|X|
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|
# O|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|X
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|
#  |O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|
#  |O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|
# O|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
#  | |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
# X| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# O| |
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# O| |X
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# O| |X
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# O|X|X
# X| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|O
# O|X|X
# X| |X
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|O|
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# X|O|
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# X|O|O
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# X|O|O
#  | |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |O
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |O
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X| |O
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X| |O
# X|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X| |O
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |O|
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |O|X
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O|O|X
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O|O|X
# X| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O| |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O|O|X
# O|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# O|O|X
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |
#  | |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|O|
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|O|X
#  | |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|O|X
#  |O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X|O|X
#  |O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O|X|
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X|X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|X|
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|O
# X|X|
# X| |
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# X| |X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# X| |X
# O|O|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# X|X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |O
# X|X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |O
# X|X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X| |O
# X|X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X| |O
# X|X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X| |O
# X|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
# X| |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |
# X| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |O
# X| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# O| |O
# X| |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|O|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
#  | |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# X|O|
#  | |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# X|O|O
#  | |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# X|O|O
#  | |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X| |
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X|O|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X|O|X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# X|O|X
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# X|O|X
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# X|O|X
# O|X|
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  | |O
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  | |O
# O|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# X| |O
# O|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# X|O|O
# O|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# X|O|O
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
# O|O|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# X| |X
# O|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# X| |X
# O|O|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  |X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |O
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
#  |X|
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
# X|X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|X|X
#  | |
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O|O|X
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# O|O|X
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
# X| |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# O| |
# X| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |O
# O| |
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |O
# O| |O
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O| |O
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|O|O
# X| |X
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O|O|X
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# O|O|X
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# X| |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X| |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X| |
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|O|
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|O|
# X|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X| |
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X| |X
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X| |X
# O| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X| |X
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X| |X
# O|O|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O| |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# X| |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X| |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X| |
# X|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X| |
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|X|
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|X|O
# X|X|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|O
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|O
# X| |
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |X
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |O
#  | |X
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
#  | |X
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
#  | |X
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
#  |X|X
# X| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# O|X|X
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# O|X|X
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |O
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |O
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |O
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
# O|X|O
# X|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|O
# X|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# O| |X
# O|O|
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|O|
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|O|X
# X| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|O|X
# X| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|O|X
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# O|O|X
# X|X|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |O|X
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |O|X
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
#  |O|X
# O|O|X
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  | |O
#  |X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
#  | |O
#  |X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
#  | |O
# X|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
#  |O|O
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# X|O|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  |X|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# O|X|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |X
# O|X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
#  | |X
# O|X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
#  | |X
# O|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|O
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# X|X|O
# O| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# X|X|O
# O|O|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  | |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  |O|
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
#  |O|
# O| |
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
#  |X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  |O|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
# X|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|O
# X|O|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
# X|O|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|X|O
# X|O|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|X|O
# X|O|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
# X|X|O
# X|O|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |X
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O|X|X
# O| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|X
# O| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|X
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O|X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O|X|
#  |X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O|X|O
#  |X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O|X|O
#  |X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O|X|O
#  |X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O|X|O
# X|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# O|X|O
# X|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# O|X|O
# X|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O| |X
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
#  |X|
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
#  |X|
#  |O|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
#  |X|
# X|O|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|O
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|O
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  |X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |O
# X| |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# X| |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|O
# X|O|X
#  |X|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  | |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# X| |O
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X| |O
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X|X|O
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X|X|O
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|X|O
# O|O|X
#
# draw
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# X| |X
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
# X|X|X
#  | |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X| |
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X| |O
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X| |O
# X| |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
# X| |O
# X| |O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |O
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |O
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |O
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X|O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X|O|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# O|X|O
# X|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# O|X|O
# X|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O| |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O|X|X
# O|X|O
#
# draw
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |X
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |X
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |X
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O| |X
#  |X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O| |X
# X|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O|O|X
# X|X|O
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X|X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
# X|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |X
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |X
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|X|X
#  | |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |O
#  |X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  | |O
#  |X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
#  | |O
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# X| |O
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# X|O|O
# O|X|O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# X|O|O
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  |X|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# O|X|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |X
# O|X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
#  | |X
# O|X|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
#  | |X
# O|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |X
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  |X|X
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  |X|X
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |O
#  |X|X
# O|O|X
#
# bot A wins
# ...
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# O|X|
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# O|X|
# O|O|X
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |X
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O| |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  | |X
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  | |X
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  | |X
# O| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
#  | |X
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O| |X
# O| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O| |X
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  |O|
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  |O|
# X|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|O
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O| |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
#  |X|O
# O| |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |O
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |O
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |O
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X|O|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|X|O
# X|O|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
# O|X|O
# X|O|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|O
# O|X|O
# X|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X|O|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
#  |O|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# X|O|
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|X
# X|O|
#  |O|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# X|O|
#  |O|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  | |O
# O|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
#  |X|O
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
#  |X|O
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# X|X|O
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X|X|O
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X|X|O
# O|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
#  | |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X| |
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# X|O|
# O| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|O
# X|O|
# O| |X
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# X|O|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|O|
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|O|
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|O|
# O| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|O|
# O|O|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# X|O|X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  | |X
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  |O|X
#  | |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|
#  |O|X
# X| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
#  |O|X
# X| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |O|O
# X|O|X
# X| |X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|O
# X|O|X
# X| |X
#
# bot B wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |O
#  |X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |O
#  |X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  | |O
#  |X|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O| |O
#  |X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# O| |O
# X|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  |X|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
# O|X|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |X
# O|X|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
#  | |X
# O|X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X| |X
# O|X|X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|
# X|O|X
# O|X|X
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|O|X
# X|O|X
# O|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O| |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O| |X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O|X|X
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |X
# O|X|X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |X
# O|X|X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O|X|X
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O|X|X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O| |X
#  | |O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
# O|O|X
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|X
# O|O|X
#  | |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O|X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O|X|
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# O|X|O
#  |X|
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O|X|O
#  |X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O|X|O
#  |X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# O|X|O
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|
# O|X|O
# X|X|O
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|X
# O|X|O
# X|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |O
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# X| |O
#  | |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# X| |O
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# X| |O
# X|O|
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  | |
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X| |
#  | |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|O|
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|O|X
#  | |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
# X|O|X
#  |O|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
# X|O|X
#  |O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O| |X
#  |X|
#  | |O
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
#  |X|
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# O|X|
#  | |O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|X
# O|X|
# X| |O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
# X| |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |
# X| |
# O| |
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |O
# X| |
# O| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |O
# X| |
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X| |
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X|X|
# O|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X|X|
# O|X|O
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|O|O
# X|X|X
# O|X|O
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O| |
# X| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|O|
# X| |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
# O|O|
# X|X|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# O|O|
# X|X|
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# O|X|
# O|O|
# X|X|X
#
# bot A wins
# Tictactoe bot training
# loading...
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
#  | |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
# O| |
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |X
# O| |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  | |X
# O| |X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  |X|X
# O| |X
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |O
#  |X|X
# O|O|X
#
# from db
# 0|1|2
# 3|4|5
# 6|7|8
#
# X| |O
#  |X|X
# O|O|X
#
# bot A wins
# Tictactoe bot training
# loading...
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  | |
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  | |
#  |X|O
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  |X|O
#  | |
#
# exploratory random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
#  |X|
#  |X|O
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
#  |O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O|O|
#
# random bs
# 0|1|2
# 3|4|5
# 6|7|8
#
# X|X|
#  |X|O
# O|O|X
#
# bot A wins
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found
# sh: 1: cls: not found

# %%
with open('test.db', 'r') as f:
    lines = f.readlines()
    print(lines)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 with open('test.db', 'r') as f:
#       2     lines = f.readlines()
#       3     print(lines)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.db'

# %%
with open('test.db', 'a') as f:
    f.write(f"{'000000000'}|{8}\n")

# %%
with open('test.db', 'r') as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['000000000|8\n']

# %%
with open('test.db', 'a') as f:
    f.write(f"{'000000001'}|{3}\n")

# %%
with open('test.db', 'r') as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['000000000|8\n', '000000001|3\n']

# %%
db = dict()
with open('test.db', 'r') as f:
    lines = f.readlines()
    for line in lines:
        k, v = line.split('|')
        if k in db.keys():
            db[k].append(int(v[:-1]))
        else:
            db[k] = [int(v[:-1])]

# %%
db
# Out:
# {'000000000': [8], '000000001': [3]}

# %%
with open('test.db', 'a') as f:
    f.write(f"{'000000000'}|{6}\n")

# %%
with open('test.db', 'r') as f:
    lines = f.readlines()
    for line in lines:
        k, v = line.split('|')
        if k in db.keys():
            list(db[k]).append(int(v[:-1]))
            db[k] = set(db[k])
        else:
            db[k] = set([int(v[:-1])])

# %%
db
# Out:
# {'000000000': {6, 8}, '000000001': {3}}
